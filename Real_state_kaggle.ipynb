# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
train = pd.read_csv("C:/Users/ankro/OneDrive/Desktop/rstrain.csv")
test = pd.read_csv("C:/Users/ankro/OneDrive/Desktop/rstest.csv")
pd.set_option('display.max_columns',None)

# %% [markdown]
# # Data Exploraty Analysis

# %%
train.sample(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 728    729          90       RL         85.0    11475   Pave   NaN      Reg
# 1386  1387          60       RL         80.0    16692   Pave   NaN      IR1
# 1209  1210          20       RL         85.0    10182   Pave   NaN      IR1
# 698    699          20       RL         65.0     8450   Pave   NaN      Reg
# 1079  1080          20       RL         65.0     8775   Pave   NaN      Reg
# 1305  1306          20       RL        108.0    13173   Pave   NaN      IR1
# 1142  1143          60       RL         77.0     9965   Pave   NaN      Reg
# 654    655          20       RL         91.0    10437   Pave   NaN      IR1
# 529    530          20       RL          NaN    32668   Pave   NaN      IR1
# 1295  1296          20       RL         70.0     8400   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(train)
prof.to_file(output_file= "C:/Users/ankro/OneDrive/Desktop/Real_state_EDA.html")
# Out:
# ...
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\ankro\anaconda3\lib\site-packages\pandas_profiling\visualisation\plot.py:154: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("RdBu").copy()
#   cmap.set_bad(cmap_bad)
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
pd.set_option('display.max_rows',None)
train.info()
#test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
train.plot(kind="scatter", x="LotArea", y="YearBuilt", alpha=0.4,
 s=train["LotArea"]/200, label="LotArea", figsize=(10,7),
 c="SalePrice", cmap=plt.get_cmap("jet"), colorbar=False,
)
plt.legend()

# %%
train.describe(include=[np.object])
# Out:
# C:\Users\ankro\AppData\Local\Temp/ipykernel_17804/2366129671.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   train.describe(include=[np.object])
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# count       1460         1460       1460       1460     1460       1460
# ...

# %% [markdown]
# Looking for missing data in both train and test dataset

# %%
missing_train = train.isnull().sum()
missing_test = test.isnull().sum()
missing_train = pd.DataFrame({'NaN_count_train': missing_train, 'NaN_percentage_train': missing_train / len(train)})
missing_test = pd.DataFrame({'NaN_count_test': missing_test, 'NaN_percentage_test': missing_test / len(test)})
missing=pd.concat([missing_train,missing_test],axis=1)
missing
# Out:
#                NaN_count_train  NaN_percentage_train  NaN_count_test  \
# Id                           0              0.000000             0.0
# MSSubClass                   0              0.000000             0.0
# MSZoning                     0              0.000000             4.0
# LotFrontage                259              0.177397           227.0
# LotArea                      0              0.000000             0.0
# Street                       0              0.000000             0.0
# Alley                     1369              0.937671          1352.0
# LotShape                     0              0.000000             0.0
# LandContour                  0              0.000000             0.0
# Utilities                    0              0.000000             2.0
# LotConfig                    0              0.000000             0.0
# LandSlope                    0              0.000000             0.0
# Neighborhood                 0              0.000000             0.0
# ...

# %%
miss_train=set(missing[missing['NaN_count_train']>0].index)
miss_test=set(missing[missing['NaN_count_test']>0].index)

# %% [markdown]
# Here we can clearly see some of the extra feature in the test data is having missing value. so we need to treat them also. We will deal this later

# %%
miss_test.difference(miss_train)
# Out:
# {'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'BsmtUnfSF',
#  'Exterior1st',
#  'Exterior2nd',
#  'Functional',
#  'GarageArea',
#  'GarageCars',
#  'KitchenQual',
#  'MSZoning',
#  'SaleType',
#  'TotalBsmtSF',
#  'Utilities'}

# %% [markdown]
# Looking for Dublicate rows in train dataset only

# %%
print(train.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Handling Missing data

# %% [markdown]
# Removing the column having high amount of missing value and rows having lowest amount of missing term

# %%
li_col=[]
li_row=[]
for k in missing[missing['NaN_percentage_train']>0.45].index.values:
    li_col.append(k)
    train.drop(columns=k,axis=1,inplace=True)# eliminating columns
for k in missing[(missing['NaN_percentage_train']<0.03)&(missing['NaN_percentage_train']!=0)].index.values:
    li_row.append(k)
    train.dropna(subset=[k],inplace=True) #eliminating rows

# %%
print('column having more than 45% data missing ',li_col)
print('column having less than 0.03% data missing ',li_row)
# Out:
# column having more than 45% data missing  ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']
# column having less than 0.03% data missing  ['MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical']

# %% [markdown]
# Similary deleting only column of test data without removing rows or lossing data

# %%
test.drop(columns=['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'],axis=1,inplace=True)

# %% [markdown]
# Left over columns having missing values

# %%
series=train.isnull().sum()[train.isnull().sum()>0].index
series
# Out:
# Index(['LotFrontage', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageQual', 'GarageCond'],
#       dtype='object')

# %% [markdown]
# Analysing the data distribution of missing columns

# %%
for i in series:
    plt.figure(figsize=(15,5))
    sns.distplot(train[i].value_counts(dropna=False),color='green',hist=True)
    sns.distplot(train[i].value_counts(dropna=True),color='red',hist=True)
    plt.show()
# Out:
# C:\Users\ankro\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ankro\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Replacing the null value with mean/meadian/mode and observing the graph similary for other columns also

# %%
train['new_LotFrontage']=train['LotFrontage'].fillna(train['LotFrontage'].mean()) # median, mode
sns.distplot(train['LotFrontage'],color='green')
sns.distplot(train['new_LotFrontage'],color='red')
# Out:
# C:\Users\ankro\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ankro\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='new_LotFrontage', ylabel='Density'>

# %% [markdown]
# After replacing we find that it distort the graph hence we will not apply this

# %%
train['old_LotFrontage']=train['LotFrontage']

# %% [markdown]
# Using KNN Imputer to impute the missing value in the dataset LotFrontage columns

# %%
from sklearn.impute import KNNImputer
knnimputer= KNNImputer(n_neighbors=3,add_indicator=True)
train['LotFrontage']=knnimputer.fit_transform(train[['LotFrontage','LotArea','TotalBsmtSF','1stFlrSF']])

# %%
test['LotFrontage']=knnimputer.fit_transform(test[['LotFrontage','LotArea','TotalBsmtSF','1stFlrSF']])

# %% [markdown]
# Taking the look at the data distribution after filling new value It seems like it fit perfect

# %%
plt.figure(figsize=(15,5))
sns.distplot(train['LotFrontage'],color='green',hist=False)
sns.distplot(train['old_LotFrontage'],color='red',hist=False)
# Out:
# C:\Users\ankro\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ankro\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='old_LotFrontage', ylabel='Density'>

# %%
train.drop('old_LotFrontage',axis=1,inplace=True)

# %%
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# GarageType      74
# GarageYrBlt     74
# GarageFinish    74
# GarageQual      74
# GarageCond      74
# dtype: int64

# %% [markdown]
# 'GarageType', 'GarageYrBlt', 'GarageFinish','GarageQual','GarageCond' all the missing value belong to the same row and give detail of same attribute of house Where the house don't have garage facility. hence we can replace this with NA or Not Applicable value

# %%
train['GarageType'].fillna('NA',inplace=True)
train['GarageYrBlt'].fillna(0,inplace=True)
train['GarageFinish'].fillna('NA',inplace=True)
train['GarageQual'].fillna('NA',inplace=True)
train['GarageCond'].fillna('NA',inplace=True)

# %%
test['GarageType'].fillna('NA',inplace=True)
test['GarageYrBlt'].fillna(0,inplace=True)
test['GarageFinish'].fillna('NA',inplace=True)
test['GarageQual'].fillna('NA',inplace=True)
test['GarageCond'].fillna('NA',inplace=True)

# %% [markdown]
# Now we will deal with the missing data befor handling category data

# %%
test_obj = test.select_dtypes(include =['object']).columns
test_num = test.select_dtypes(exclude =['object']).columns

# %%
for i in test_obj:
    val= test[i].mode().values[0]
    test[i].fillna(val,inplace=True)

# %%
for i in test_num:
    val=test[i].mean()
    test[i].fillna(val,inplace=True)

# %% [markdown]
#  All the missing value is the data set is either remove or imputed

# %%
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
test.isnull().sum()[test.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # Handling categroy data

# %%
df_obj=train.select_dtypes(include =['object'])

# %%
df_obj.describe().columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# Taking a look what are different ratio of the unqiue value in every category columns.Then deciding weather it is nominal or category data type

# %%
dict_1={}
for i in df_obj.columns:
    li=[]
    val=train.groupby(by=i).sum()['SalePrice']
    num=train[i].value_counts(dropna=False)
    avg= val/num
    print(pd.concat([val,num,avg],axis=1).sort_values(by=0))
    li=list(pd.concat([val,num,avg],axis=1).sort_values(by=0).index.values)
    dict_1[i]=li
# Out:
#          SalePrice  MSZoning              0
# C (all)     745280        10   74528.000000
# RM        27192569       214  127068.079439
# RH         1960934        15  130728.933333
# RL       214478068      1111  193049.566157
# FV        13323064        62  214888.129032
#       SalePrice  Street              0
# Grvl     781143       6  130190.500000
# Pave  256918772    1406  182730.278805
#      SalePrice  LotShape              0
# Reg  147401800       886  166367.720090
# IR1   98473582       476  206877.273109
# IR3    2160365        10  216036.500000
# IR2    9664168        40  241604.200000
#      SalePrice  LandContour              0
# Bnk    8777735           61  143897.295082
# Lvl  230137883         1267  181640.002368
# Low    7207600           34  211988.235294
# HLS   11576697           50  231533.940000
#         SalePrice  Utilities              0
# NoSeWa     137500          1  137500.000000
# AllPub  257562415       1411  182538.919206
# ...

# %% [markdown]
# Here we can see that the all objective feature in the dataset and the most important value within each category when compare with total sales value after arranging them we are redady to apply ordinal encoder

# %%
dict_1.values()
# Out:
# dict_values([['C (all)', 'RM', 'RH', 'RL', 'FV'], ['Grvl', 'Pave'], ['Reg', 'IR1', 'IR3', 'IR2'], ['Bnk', 'Lvl', 'Low', 'HLS'], ['NoSeWa', 'AllPub'], ['Inside', 'FR2', 'Corner', 'FR3', 'CulDSac'], ['Gtl', 'Mod', 'Sev'], ['MeadowV', 'IDOTRR', 'BrDale', 'BrkSide', 'OldTown', 'Edwards', 'Blueste', 'Sawyer', 'SWISU', 'NPkVill', 'NAmes', 'Mitchel', 'NWAmes', 'SawyerW', 'Gilbert', 'Blmngtn', 'CollgCr', 'Crawfor', 'ClearCr', 'Somerst', 'Veenker', 'Timber', 'StoneBr', 'NridgHt', 'NoRidge'], ['Artery', 'RRAe', 'Feedr', 'RRAn', 'Norm', 'RRNe', 'RRNn', 'PosN', 'PosA'], ['RRNn', 'Artery', 'Feedr', 'RRAn', 'Norm', 'RRAe', 'PosN', 'PosA'], ['2fmCon', 'Twnhs', 'Duplex', 'TwnhsE', '1Fam'], ['1.5Unf', 'SFoyer', '1.5Fin', '2.5Unf', 'SLvl', '1Story', '2Story', '2.5Fin'], ['Gambrel', 'Gable', 'Mansard', 'Flat', 'Hip', 'Shed'], ['Roll', 'ClyTile', 'Metal', 'CompShg', 'Tar&Grv', 'WdShake', 'Membran', 'WdShngl'], ['BrkComm', 'CBlock', 'AsbShng', 'Wd Sdng', 'MetalSd', 'WdShing', 'HdBoard', 'Stucco', 'Plywoo
# ...

# %% [markdown]
# Since most of the objective data in this dataset is related or subjected to organised so its category datatype

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc=OrdinalEncoder(categories=[['C (all)', 'RM', 'RH', 'RL', 'FV'], ['Grvl', 'Pave'], 
['Reg', 'IR1', 'IR3', 'IR2'], ['Bnk', 'Lvl', 'Low', 'HLS'], ['NoSeWa', 'AllPub'], 
['Inside', 'FR2', 'Corner', 'FR3', 'CulDSac'], ['Gtl', 'Mod', 'Sev'], 
['MeadowV', 'IDOTRR', 'BrDale', 'BrkSide', 'OldTown', 'Edwards', 'Blueste', 'Sawyer', 'SWISU', 'NPkVill', 'NAmes', 
 'Mitchel', 'NWAmes', 'SawyerW', 'Gilbert', 'Blmngtn', 'CollgCr', 'Crawfor', 'ClearCr', 'Somerst', 'Veenker', 'Timber', 
 'StoneBr', 'NridgHt', 'NoRidge'], ['Artery', 'RRAe', 'Feedr', 'RRAn', 'Norm', 'RRNe', 'RRNn', 'PosN', 'PosA'], 
['RRNn', 'Artery', 'Feedr', 'RRAn', 'Norm', 'RRAe', 'PosN', 'PosA'], ['2fmCon', 'Twnhs', 'Duplex', 'TwnhsE', '1Fam'], 
['1.5Unf', 'SFoyer', '1.5Fin', '2.5Unf', 'SLvl', '1Story', '2Story', '2.5Fin'], ['Gambrel', 'Gable', 'Mansard', 'Flat', 
'Hip', 'Shed'], ['Roll', 'ClyTile', 'Metal', 'CompShg', 'Tar&Grv', 'WdShake', 'Membran', 'WdShngl'], 
['BrkComm', 'CBlock', 'AsbShng', 'Wd Sdng', 'MetalSd', 'WdShing', 'HdBoard', 'Stucco', 'Plywood', 'BrkFace', 'VinylSd', 
 'CemntBd', 'Stone', 'ImStucc'], ['CBlock', 'AsbShng', 'Brk Cmn', 'Wd Sdng', 'MetalSd', 'AsphShn', 'Stucco', 'Wd Shng', 
'HdBoard', 'Plywood', 'Stone', 'BrkFace', 'VinylSd', 'CmentBd', 'ImStucc', 'Other'], ['BrkCmn', 'None', 'BrkFace', 'Stone'],
['Fa', 'TA', 'Gd', 'Ex'], ['Po', 'Fa', 'Gd', 'TA', 'Ex'], ['BrkTil', 'CBlock', 'Stone', 'Wood', 'PConc'],
['Fa', 'TA', 'Gd', 'Ex'], ['Po', 'Fa', 'TA', 'Gd'], ['No', 'Mn', 'Av', 'Gd'], ['Rec', 'BLQ', 'LwQ', 'ALQ', 'Unf', 'GLQ'], 
['BLQ', 'LwQ', 'Rec', 'GLQ', 'Unf', 'ALQ'], ['Grav', 'OthW', 'GasW', 'GasA'], ['Po', 'Fa', 'TA', 'Gd', 'Ex'], ['N', 'Y'], 
['Mix', 'FuseP', 'FuseF', 'FuseA', 'SBrkr'], ['Fa', 'TA', 'Gd', 'Ex'], ['Maj2', 'Sev', 'Min2', 'Maj1', 'Min1', 'Typ', 'Mod']
, ['NA', 'CarPort', 'Detchd', '2Types', 'Basment', 'Attchd', 'BuiltIn'], ['NA', 'Unf', 'RFn', 'Fin'], 
['Po', 'NA', 'Fa', 'TA', 'Gd', 'Ex'], ['NA', 'Po', 'Fa', 'Ex', 'Gd', 'TA'], ['N', 'P', 'Y'], ['Oth', 'ConLD', 'ConLw', 
'COD', 'WD', 'ConLI', 'CWD', 'Con', 'New'], ['AdjLand', 'Abnorml', 'Family', 'Normal', 'Alloca', 'Partial']])

# %%
train[df_obj.columns]=ord_enc.fit_transform(train[df_obj.columns])

# %% [markdown]
# There are some few feature where we find some new category object so replacing them with others values

# %%
test['Exterior1st'].replace('AsphShn','BrkComm',inplace=True)
test['Foundation'].replace('Slab','Wood',inplace=True)
test['Heating'].replace('Wall','Grav',inplace=True)

# %% [markdown]
# Applying the encoder to test dataset

# %%
test[df_obj.columns]=ord_enc.transform(test[df_obj.columns])

# %%
#from sklearn.preprocessing import OneHotEncoder
#o_h_enc=OneHotEncoder(drop='first',sparse=False)
#df=o_h_enc.fit_transform(train[df_obj.columns])

# %% [markdown]
# # Outlier Data Handling

# %% [markdown]
# In housing sector any outlier is having a direct affect on the total cost price of the house. so we need to understand the outlier before treating them.

# %%
for i in train.columns:
    if i=='SalePrice':
        continue
    plt.figure(figsize=(18,5))
    plt.subplot(1,3,1)
    sns.distplot(train[i])
    plt.subplot(1,3,2)
    sns.boxplot(train[i])
    plt.subplot(1,3,3)
    stats.probplot(train[i],dist='norm',plot=plt)
    print(train[i].skew())
    plt.show()
# Out:
# C:\Users\ankro\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ankro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0.007357667144697328
# ...

# %% [markdown]
# # Feature selection

# %% [markdown]
# First finding the strong corelation between the salesPrice column wrt to all others columns

# %%
#ab=np.sum((train['OverallQual']-np.mean(train['OverallQual']))*(train['SalePrice']-np.mean(train['SalePrice'])),axis=None)
#a = np.sum(pow(train['OverallQual']-np.mean(train['OverallQual']),2),axis=None)
#b = np.sum(pow(train['SalePrice']-np.mean(train['SalePrice']),2),axis=None)
#ab/pow((a*b),0.5)

# %%
sel_corr=train.corr()[(train.corr()>0.5) | (train.corr()<-0.5)]['SalePrice'].dropna()
print(sel_corr)
train[sel_corr.index].describe()
# Out:
# Neighborhood    0.694579
# OverallQual     0.786765
# YearBuilt       0.518736
# YearRemodAdd    0.500266
# ExterQual       0.675683
# BsmtQual        0.643050
# TotalBsmtSF     0.611084
# 1stFlrSF        0.614753
# GrLivArea       0.711080
# FullBath        0.575604
# KitchenQual     0.654076
# TotRmsAbvGrd    0.545540
# GarageFinish    0.542399
# GarageCars      0.641825
# GarageArea      0.621095
# SalePrice       1.000000
# Name: SalePrice, dtype: float64
#        Neighborhood  OverallQual    YearBuilt  YearRemodAdd    ExterQual  \
# count   1412.000000  1412.000000  1412.000000   1412.000000  1412.000000
# mean      12.063739     6.138810  1971.428470   1985.191218     1.402266
# std        6.407509     1.357655    30.371732     20.462484     0.574384
# min        0.000000     1.000000  1872.000000   1950.000000     0.000000
# 25%        7.000000     5.000000  1954.000000   1968.000000     1.000000
# 50%       12.000000     6.000000  1973.000000   1994.000000     1.000000
# ...

# %% [markdown]
# plotting heat map of only selected strong correlations

# %%
temp=train[sel_corr.index].corr().sort_values('SalePrice',ascending=False)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data=temp,vmin=-1,vmax=1,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
#  Among the strongest feature finding low co-linearity among themself

# %%
for i in range((temp.shape[0])):
    for j in range(temp.shape[1]):
        if (temp.iloc[i,j]<0.2) and (temp.iloc[i,j]>-0.2):
            print(temp.index[i],temp.columns[j],temp.iloc[i,j])
# Out:
# GrLivArea YearBuilt 0.19159150499309957
# TotRmsAbvGrd YearBuilt 0.09179228442115919
# TotRmsAbvGrd YearRemodAdd 0.18921595016281337
# YearBuilt GrLivArea 0.19159150499309957
# YearBuilt TotRmsAbvGrd 0.09179228442115919
# YearRemodAdd TotRmsAbvGrd 0.18921595016281337

# %%
x=train.drop('SalePrice',axis=1)
y=train['SalePrice']

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# Now using Sequential selector to find best feature to model by testing on different model

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()
from sklearn.linear_model import Lasso
ls= Lasso()
from sklearn.linear_model import Ridge
re= Ridge()
from sklearn.tree import DecisionTreeRegressor
dtr= DecisionTreeRegressor()
from sklearn.linear_model import ElasticNet
enr= ElasticNet()
from sklearn.neighbors import KNeighborsRegressor
knr = KNeighborsRegressor()
from sklearn.svm import SVR
svr=SVR()

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Getting View which algorithum is performing well

# %%
model =[('lnr_rgr',lr),('lss_rgr',ls),('rde_rgr',re),('dtr_rgr',dtr),('els_rgr',enr),('knn_rgr',knr),('svr_rgr',svr)]
for est in model:
    score = cross_val_score(est[1],x,y,scoring='neg_root_mean_squared_error',cv=5,n_jobs=-1)
    print(est[0],np.round(np.mean(score),2))
# Out:
# lnr_rgr -33796.5
# lss_rgr -33794.68
# rde_rgr -33783.99
# dtr_rgr -42119.51
# els_rgr -34396.69
# knn_rgr -48379.16
# svr_rgr -81097.23

# %% [markdown]
# Finding best feature for each algorithum (linear, lasso, ridge, Elastic, decision_Tree, KNN)

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
forward_feature_selection = SequentialFeatureSelector(enr,k_features=15,forward=True,scoring='r2',cv=5,verbose=2)
feature=forward_feature_selection.fit(x,y)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  76 out of  76 | elapsed:    0.9s finished
#
# [2022-12-07 21:00:35] Features: 1/15 -- score: 0.5920957056756804[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:    0.8s finished
#
# [2022-12-07 21:00:36] Features: 2/15 -- score: 0.6870533308059495[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed:    0.8s finished
#
# [2022-12-07 21:00:37] Features: 3/15 -- score: 0.7502179941397491[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
f_feature=list(feature.k_feature_names_)
feature.k_feature_names_
# Out:
# ('MSSubClass',
#  'Neighborhood',
#  'OverallQual',
#  'OverallCond',
#  'RoofStyle',
#  'RoofMatl',
#  'ExterQual',
#  'BsmtQual',
#  'BsmtExposure',
#  'BsmtFinSF1',
#  'GrLivArea',
#  'KitchenQual',
#  'GarageCars',
#  'ScreenPorch',
#  'SaleCondition')

# %% [markdown]
# lnr/lass/rid/elastic=('MSSubClass','Neighborhood','OverallQual','OverallCond','RoofMatl','MasVnrArea','BsmtQual','BsmtExposure','BsmtFinSF1','GrLivArea','KitchenQual','Fireplaces','GarageYrBlt','GarageCars','SaleCondition')
#
# dsc=('Street','Utilities','LandSlope','Neighborhood','Condition2','BldgType','OverallQual','CentralAir','BsmtHalfBath','Fireplaces','GarageCars','GarageQual','GarageCond','MiscVal','SaleType')
#
# knn =
# ('MSSubClass','LotArea','Street','Utilities','Neighborhood','OverallQual','OverallCond','YearBuilt','BsmtQual','CentralAir','1stFlrSF')

# %%
x= train[['MSSubClass','LotArea','Street','Utilities','Neighborhood','OverallQual','OverallCond','YearBuilt','BsmtQual',
            'CentralAir','1stFlrSF']]
y=train['SalePrice']

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = { 
    'n_neighbors':[3,5,7],
    'weights': ['uniform','distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'leaf_size': [20,30,40],
    'p':[1,2,3,5]
}

# %%
reg = GridSearchCV(knr,param_grid=param_grid,n_jobs=-1)
reg.fit(x,y)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [20, 30, 40], 'n_neighbors': [3, 5, 7],
#                          'p': [1, 2, 3, 5],
#                          'weights': ['uniform', 'distance']})

# %%
print(reg.best_score_)
reg.best_params_
# Out:
# 0.4756466504610983
# {'algorithm': 'ball_tree',
#  'leaf_size': 20,
#  'n_neighbors': 5,
#  'p': 1,
#  'weights': 'distance'}

# %% [markdown]
#  linear = 'fit_intercept': True, 'normalize': False, 'positive': False
#
#  lasso = 'alpha': 0.1,'max_iter': 5000,'positive': False,'selection': 'random','warm_start': True
#
#  Ridge =  'alpha': 0.9, 'max_iter': 1000, 'normalize': True, 'random_state': 42
#
#  Elastic= 'alpha': 0.1,'l1_ratio': 0.9,'max_iter': 5000,'normalize': False,'random_state': None,'selection': 'random','tol': 0.001,'warm_start': True
#
#  decesion Tree= 'criterion': 'mse','max_depth': 95,'max_features': 'auto','max_leaf_nodes': None,'min_impurity_decrease': 0.0,'min_impurity_split': 0.5,'min_samples_leaf': 3,'min_samples_split': 4,'min_weight_fraction_leaf': 0.0,'random_state': None,'splitter': 'random'': 5,'min_weight_fraction_leaf': 0.0,'random_state': None,'splitter': 'random'
#
#  don't use knn use score less than 50%
#
#  (KNN = 'algorithm': 'ball_tree','leaf_size': 20,'n_neighbors': 5,'p': 1,'weights': 'distance')

# %% [markdown]
# # Scaling Data

# %%
x_train=train[['MSSubClass','LandSlope','CentralAir','BldgType','SaleType','Utilities','GarageCond','GarageCars','MiscVal',
               'BsmtFinSF1','Neighborhood','GrLivArea','Street','OverallCond','KitchenQual','GarageQual','BsmtQual',
               'MasVnrArea','Fireplaces','BsmtExposure','GarageYrBlt','Condition2','RoofMatl','OverallQual','SaleCondition',
               'BsmtHalfBath']]
y_train=train['SalePrice']

# %%
from sklearn.preprocessing import  RobustScaler # MinMaxScaler #StandardScaler
scale= RobustScaler()
x_train = pd.DataFrame(scale.fit_transform(x_train),columns=x_train.columns)

# %%
print(x_train.shape,y_train.shape)
# Out:
# (1412, 26) (1412,)

# %% [markdown]
# # Final Model and Making Prediction

# %% [markdown]
# Using ensemble Voting Technique

# %%
#lnr_rgr=LinearRegression(fit_intercept = True, normalize= False, positive= False)

lsso_rgr= Lasso(alpha= 0.1,max_iter= 5000,positive= False,selection= 'random',warm_start= True)

rdg_rgr= Ridge(alpha= 0.9,max_iter= 1000, normalize= True,random_state= 42)

#knn_rgr= KNeighborsRegressor(algorithm= 'ball_tree',leaf_size= 20,n_neighbors= 5,p= 1,weights= 'distance')

dcs_tree= DecisionTreeRegressor(criterion='mse',max_depth= 95,max_features= 'auto',max_leaf_nodes= None,min_impurity_decrease= 0.0,min_impurity_split= 0.5,min_samples_leaf= 3,min_samples_split= 4,min_weight_fraction_leaf= 0.0,random_state= None,splitter='random')

elstc_rgr= ElasticNet(alpha= 0.1,l1_ratio= 0.9,max_iter= 5000,normalize=False,random_state= None,selection= 'random',tol= 0.001,warm_start= True)

# %%
estimators = [('dcs_tree',dcs_tree),('elstc_rgr',elstc_rgr),('lsso_rgr',lsso_rgr)]

# %%
from sklearn.ensemble import VotingRegressor
vr = VotingRegressor(estimators=estimators,n_jobs=-1) 
score = cross_val_score(vr,x_train,y_train,scoring='neg_root_mean_squared_error',cv=10)
print(np.round(np.mean(score),2))
# Out:
# -29715.4

# %%
vr.fit(x_train,y_train)
# Out:
# VotingRegressor(estimators=[('dcs_tree',
#                              DecisionTreeRegressor(max_depth=95,
#                                                    max_features='auto',
#                                                    min_impurity_split=0.5,
#                                                    min_samples_leaf=3,
#                                                    min_samples_split=4,
#                                                    splitter='random')),
#                             ('elstc_rgr',
#                              ElasticNet(alpha=0.1, l1_ratio=0.9, max_iter=5000,
#                                         selection='random', tol=0.001,
#                                         warm_start=True)),
#                             ('lsso_rgr',
#                              Lasso(alpha=0.1, max_iter=5000, selection='random',
#                                    warm_start=True))],
#                 n_jobs=-1)

# %%
x_test=test[['MSSubClass','LandSlope','CentralAir','BldgType','SaleType','Utilities','GarageCond','GarageCars','MiscVal',
               'BsmtFinSF1','Neighborhood','GrLivArea','Street','OverallCond','KitchenQual','GarageQual','BsmtQual',
               'MasVnrArea','Fireplaces','BsmtExposure','GarageYrBlt','Condition2','RoofMatl','OverallQual','SaleCondition',
               'BsmtHalfBath']]

# %%
y_pred=vr.predict(x_test)

# %%
test['sales_price']=y_pred

# %%
df=test[['Id','sales_price']]

# %%
df.shape
# Out:
# (1459, 2)

# %%
df.to_csv("C:/Users/ankro/OneDrive/Desktop/rs.csv",index=False)
